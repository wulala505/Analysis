# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import matplotlib
[f.name for f in matplotlib.font_manager.fontManager.ttflist]
# Out:
# ['STIXSizeThreeSym',
#  'cmss10',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'cmmi10',
#  'DejaVu Sans Display',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'STIXSizeThreeSym',
#  'STIXSizeFourSym',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'STIXSizeTwoSym',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'STIXSizeFiveSym',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'DejaVu Serif Display',
#  'STIXGeneral',
#  'cmb10',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'cmr10',
#  'STIXSizeTwoSym',
#  'cmtt10',
#  'cmsy10',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'STIXSizeOneSym',
#  'STIXSizeOneSym',
#  'cmex10',
#  'STIXSizeFourSym',
#  'Arial Narrow',
#  'Courier New',
#  'System Font',
#  'Luxi Sans',
#  'DIN Alternate',
#  'STIXSizeFourSym',
#  'Luminari',
#  'Times New Roman',
#  'Bradley Hand',
#  'Tahoma',
#  'Luxi Serif',
#  'System Font',
#  'Bitstream Vera Sans',
#  'STIXIntegralsSm',
# ...

# %%
plt.rcParams['font.family']='Weibei TC'

# %%
# 實價登錄 (http://data.gov.tw/node/6213)
df = pd.read_csv('/Users/wulala/Downloads/lvr_landcsv/A_LVR_LAND_A.CSV',encoding='big5')

# %%
df[:10]
# Out:
#   鄉鎮市區          交易標的             土地區段位置或建物區門牌  土地移轉總面積平方公尺 都市土地使用分區  \
# 0  中正區            建物        臺北市中正區齊東街82巷1~30號         0.00      NaN
# 1  中正區            建物        臺北市中正區齊東街82巷1~30號         0.00      NaN
# 2  中正區            建物        臺北市中正區齊東街82巷1~30號         0.00      NaN
# 3  信義區            車位      臺北市信義區信義路四段391~420號         0.16        商
# 4  中山區  房地(土地+建物)+車位      臺北市中山區植福路286巷31~60號        66.87       其他
# 5  大安區            車位     臺北市大安區市民大道四段121~150號         0.02        住
# 6  中正區     房地(土地+建物)           臺北市中正區惠安街1~30號        26.31        住
# 7  大安區     房地(土地+建物)    臺北市大安區新生南路一段161巷1~30號        57.61        住
# 8  松山區            車位        臺北市松山區延吉街46巷1~30號         8.25        住
# 9  中山區     房地(土地+建物)  臺北市中山區民權東路二段113巷1弄1~30號        45.46        住
#
#    非都市土地使用分區  非都市土地使用編定    交易年月日      交易筆棟數            移轉層次  \
# 0        NaN        NaN  1040520  土地0建物1車位0              二層
# 1        NaN        NaN  1040304  土地0建物1車位0              二層
# ...

# %%
df.corr()
# Out:
#              土地移轉總面積平方公尺  非都市土地使用分區  非都市土地使用編定     交易年月日    建築完成年月  \
# 土地移轉總面積平方公尺     1.000000        NaN        NaN  0.012676 -0.044343
# 非都市土地使用分區            NaN        NaN        NaN       NaN       NaN
# 非都市土地使用編定            NaN        NaN        NaN       NaN       NaN
# 交易年月日           0.012676        NaN        NaN  1.000000 -0.227477
# 建築完成年月         -0.044343        NaN        NaN -0.227477  1.000000
# 建物移轉總面積平方公尺    -0.001851        NaN        NaN -0.167500  0.309046
# 建物現況格局-房       -0.038205        NaN        NaN  0.110013 -0.173096
# 建物現況格局-廳       -0.054759        NaN        NaN  0.097287 -0.084513
# 建物現況格局-衛       -0.040745        NaN        NaN  0.041428 -0.055909
# 總價元             0.099814        NaN        NaN -0.221252  0.272443
# 單價每平方公尺        -0.084734        NaN        NaN -0.238852  0.284237
# 車位移轉總面積平方公尺    -0.005521        NaN        NaN -0.181657  0.434296
# 車位總價元          -0.008470        NaN        NaN -0.251057  0.364790
#
# ...

# %%
df[1:]
# Out:
#      鄉鎮市區          交易標的             土地區段位置或建物區門牌  土地移轉總面積平方公尺 都市土地使用分區  \
# 1     中正區            建物        臺北市中正區齊東街82巷1~30號         0.00      NaN
# 2     中正區            建物        臺北市中正區齊東街82巷1~30號         0.00      NaN
# 3     信義區            車位      臺北市信義區信義路四段391~420號         0.16        商
# 4     中山區  房地(土地+建物)+車位      臺北市中山區植福路286巷31~60號        66.87       其他
# 5     大安區            車位     臺北市大安區市民大道四段121~150號         0.02        住
# 6     中正區     房地(土地+建物)           臺北市中正區惠安街1~30號        26.31        住
# 7     大安區     房地(土地+建物)    臺北市大安區新生南路一段161巷1~30號        57.61        住
# 8     松山區            車位        臺北市松山區延吉街46巷1~30號         8.25        住
# 9     中山區     房地(土地+建物)  臺北市中山區民權東路二段113巷1弄1~30號        45.46        住
# 10    中正區  房地(土地+建物)+車位         臺北市中正區八德路一段1~30號       105.23       其他
# 11    中正區     房地(土地+建物)        臺北市中正區水源路31巷1~30號        22.66        住
# 12    松山區  房地(土地+建物)+車位        臺北市松山區三民路43巷1~30號        24.18        住
# ...

# %%
plt.rcParams['axes.unicode_minus']=False
df.plot(kind='scatter',title='散步圖（高度正相關）',figsize=(6,4),x ='總價元',y='建物移轉總面積平方公尺',marker='+')
# Out:
# /Users/wulala/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['Weibei TC'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
df.plot(kind='scatter',title='中度相關',figsize=(6,4),x='建物現況格局-房',y='建物現況格局-衛',marker='+')
# Out:
# /Users/wulala/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['Weibei TC'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
df.plot(kind='scatter',title='低度相關',figsize=(6,4),x='建物現況格局-房',y='總價元',marker='+')
# Out:
# /Users/wulala/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['Weibei TC'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
